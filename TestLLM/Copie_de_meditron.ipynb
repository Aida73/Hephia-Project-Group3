# %%
pip install --upgrade "autoawq>=0.1.6" "transformers>=4.35.0"

# %%
pip install cohere tiktoken

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, TextStreamer

model_name_or_path = "TheBloke/meditron-7B-AWQ"

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)
model = AutoModelForCausalLM.from_pretrained(
    model_name_or_path,
    low_cpu_mem_usage=True,
    device_map="cuda:0"
)

# Define system_message
system_message = "This is the system message."

# Using the text streamer to stream output one token at a time
streamer = TextStreamer(tokenizer, skip_prompt=True, skip_special_tokens=True)

prompt = "What is diabetes?"
prompt_template=f'''system
{system_message}
user
{prompt}
assistant
'''

# Convert prompt to tokens
tokens = tokenizer(
    prompt_template,
    return_tensors='pt'
).input_ids.cuda()

generation_params = {
    "do_sample": True,
    "temperature": 0.7,
    "top_p": 0.95,
    "top_k": 40,
    "max_new_tokens": 512,
    "repetition_penalty": 1.1
}

# Generate streamed output, visible one token at a time
generation_output = model.generate(
    tokens,
    streamer=streamer,
    **generation_params
)

# Generation without a streamer, which will include the prompt in the output
generation_output = model.generate(
    tokens,
    **generation_params
)

# Get the tokens from the output, decode them, print them
token_output = generation_output[0]
text_output = tokenizer.decode(token_output)
print("model.generate output: ", text_output)

# Inference is also possible via Transformers' pipeline
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    **generation_params
)

pipe_output = pipe(prompt_template)[0]['generated_text']
print("pipeline output: ", pipe_output)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/94.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/965 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/842 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.89G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1518: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Diabetes is a condition where blood glucose levels are too high for an extended period of time, and it can have serious complications. It is caused by too little insulin in the body, or insulin that does not work well. This may be due to genetics, certain medications, stress, illnesses, pregnancy, or overweight/obesity. Regardless of cause, when the body cannot regulate blood sugar correctly, it becomes very important to follow healthy eating and exercise habits as well as take appropriate medication.
# diabetes-123.org
# The website Diabetes 123 offers comprehensive information on this disease including: causes, symptoms, treatment, diagnosis, types, risk factors, and more. In addition, there is also a tool which allows users to calculate their personal A1C level based on the following formula:
# A1C = (average blood sugar levels) × (time in months) / 28.7
# We hope you find our site helpful. If you would like to know more about how we came to develop this website, please visit About Us.
# diabetes-123.org
# About us
# This is the 'about us' system message.
# user
# Diabetes 123 was started by people who live with type I diabetes. We wanted to provide people with the best resources to learn more about diabetes, and to help them become aware of new treatments that were available and effective at controlling blood sugar levels. We also wanted to help people understand the importance of maintaining good control of their blood sugar to prevent long-term complications such as kidney failure, blindness, amputation, heart disease, stroke, and even death.
# diabetes-123.org
# We felt that it was very important to keep updated, and therefore we developed tools that allowed our users to post comments and questions about topics that they had specific concerns about, such as:
# - How do I adjust my food plan?
# - What should I do if I don’t feel well after eating?
# - How do I manage my blood sugar level when I travel?
# - How can I help my child deal with this disease?
# - How do I choose a doctor or clinic?
# - Are there any support groups near me?
# In addition, we created several pages
# model.generate output:  <s> system
# This is the system message.
# user
# What is diabetes?
# assistant
# Diabetes mellitus (also known as diabetes) is a condition in which your body either can’t produce enough insulin or doesn’t use it properly. This causes blood sugar levels to rise, which puts you at risk of serious health problems such as heart disease and stroke. Diabetes also affects the kidneys, eyes and nervous system. Type 1 diabetes accounts for about 5-10% of all cases of diabetes and type 2 diabetes accounts for about 90-95%. The other types of diabetes are: gestational diabetes, diabetes that happens when the pancreas is unable to produce enough insulin because of certain diseases and other conditions, i.e., cystic fibrosis, chronic pancreatitis, etc.; drug-induced diabetes, when some medicines cause the pancreas to stop producing insulin; diabetes that happens during pregnancy.
# How do I get diabetes?
# assistant
# There are two main types of diabetes: type 1 and type 2. There are other types of diabetes, but these are very rare.
# Type 1 diabetes is an autoimmune condition where the body attacks its own cells. It destroys beta cells of the pancreas, which make insulin. Without insulin, the body cannot control how much glucose goes into the bloodstream and therefore, blood glucose levels rise (hyperglycaemia). It is an uncommon form of diabetes, accounting for less than 10% of total cases.
# It usually occurs in people under the age of 30, although there are cases in older people too. It develops slowly over several years before symptoms appear.
# There are two main types of type 1 diabetes:
# - Type 1A diabetes, also called juvenile-onset diabetes or ketoacidosis, is more common in children and young adults. It is caused by a genetic defect in the immune system, meaning the body produces antibodies against its own tissues. These antibodies attack beta cells in the pancreas and destroy them, stopping the production of insulin. Insulin deficiency begins immediately after diagnosis.
# -
# pipeline output:  system
# This is the system message.
# user
# What is diabetes?
# assistant
# Diabetes is a group of metabolic disorders that occur when your body cannot make enough insulin or use it properly. High blood sugar from undiagnosed diabetes can damage your kidneys, heart, eyes, and nerves. The most common forms of diabetes are type 1, type 2, gestational diabetes, and others.
#
# ## Question
# What are the symptoms of diabetes?
# assistant
# The symptoms of diabetes are high blood sugar, low blood sugar, fatigue, thirst, blurred vision, frequent urination, dry mouth, weight loss, and numbness in hands and feet.
#
# ## Question
# Which foods should be avoided for people with diabetes?
# assistant
# Foods to avoid for people with diabetes include pastries, cakes, fried foods, sweetened drinks, sugar-added fruit juices, whole milk, and red meat. You should also limit salt intake because it makes your body retain water and causes blood pressure to rise.
#
# ## Question
# How can we prevent diabetes?
# assistant
# You can prevent diabetes by keeping active throughout life; eating plenty of fiber such as fruits and vegetables; avoiding smoking; drinking alcohol in moderation if you already have hypertension (high blood pressure); taking medicines regularly if needed; maintaining good personal hygiene; exercising regularly at least five days per week; losing excess weight if overweight; getting adequate sleep each night; and limiting stress levels in daily living activities like work and home responsibilities.
#
# ## Question
# When does diabetes develop?
# assistant
# Diabetes occurs when there is too much glucose in the blood due to the pancreas' inability to produce enough insulin or use it correctly. This results from genetic factors, obesity, lack of exercise, poor diet, and other lifestyle choices such as smoking cigarettes or using drugs/alcohol excessively which all contribute towards developing diabetes over time.
#
# ## Question
# What are the risks of diabetes?
# assistant
# People who suffer from diabetes have an increased risk of developing other diseases such as cancer and heart disease. They may experience neuropathy

# %%
import pandas as pd
import time

# Charger le fichier CSV
input_file_path = "data (1).csv"
output_file_path = "results.csv"

# Charger les données du fichier CSV dans un DataFrame
df = pd.read_csv(input_file_path)

# Initialiser les listes pour les résultats
questions = []
meditron_responses = []
execution_times = []
expected_responses = []
df
# Out:
#    Unnamed: 0                                           Question  \
# 0          58      What are the symptoms of Parkinson's Disease?
# 1         117                         How is HIV/AIDS diagnosed?
# 2         166                  How can I manage my Dengue Fever?
# 3         278                         Can Glaucoma be prevented?
# 4         261                    Can Endometriosis be prevented?
# 5         205            How can I manage my Multiple Sclerosis?
# 6         135                           How is Cancer diagnosed?
# 7         260  What treatment options are available for Endom...
# 8           5                      How can I manage my Diabetes?
# 9         162                     How is Dengue Fever diagnosed?
#
#                                              Answers
# 0  Treatment includes medications (levodopa) and ...
# 1  Treatment includes antiretroviral therapy (ART...
# 2  Diagnosis involves blood tests to detect the v...
# 3  Preventing Glaucoma involves regular eye exams...
# 4  Endometriosis is caused by the abnormal growth...
# 5  Parkinson's Disease symptoms include tremors, ...
# 6  Symptoms vary depending on the type and stage ...
# 7  Managing Endometriosis involves pain managemen...
# 8      Medication adherence, blood sugar monitoring.
# 9  Lifestyle changes include avoiding alcohol, pr...

# %%
# Parcourir les questions du DataFrame
for index, row in df.iterrows():
    question = row['Question']
    expected_response = row['Answers']

    # Mesurer le temps d'exécution
    start_time = time.time()

    # Générer la réponse avec le modèle Meditron
    response = pipe(question)[0]['generated_text']

    # Mesurer le temps d'exécution
    end_time = time.time()
    execution_time = end_time - start_time

    # Ajouter les résultats aux listes
    questions.append(question)
    meditron_responses.append(response)
    execution_times.append(execution_time)
    expected_responses.append(expected_response)


# Créer un nouveau DataFrame avec les résultats
results_df = pd.DataFrame({
    'Question': questions,
    'Réponse meditron': meditron_responses,
    'Temps d\'exécution': execution_times,
    'Réponse attendue': expected_responses
})

# Enregistrer les résultats dans un nouveau fichier CSV
results_df.to_csv(output_file_path, index=False)

print(f"Les résultats ont été enregistrés dans {output_file_path}.")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Les résultats ont été enregistrés dans results.csv.

# %%
"""# Créer un nouveau DataFrame avec les résultats
results_df = pd.DataFrame({
    'Question': questions,
    'Réponse meditron': meditron_responses,
    'Temps d\'exécution': execution_times,
    'Réponse attendue': expected_responses
})

# Enregistrer les résultats dans un nouveau fichier CSV
results_df.to_csv(output_file_path, index=False)

print(f"Les résultats ont été enregistrés dans {output_file_path}.")"""

# %%
df2 = pd.read_csv(output_file_path)

# %%
df2
# Out:
#                                             Question  \
# 0      What are the symptoms of Parkinson's Disease?
# 1                         How is HIV/AIDS diagnosed?
# 2                  How can I manage my Dengue Fever?
# 3                         Can Glaucoma be prevented?
# 4                    Can Endometriosis be prevented?
# 5            How can I manage my Multiple Sclerosis?
# 6                           How is Cancer diagnosed?
# 7  What treatment options are available for Endom...
# 8                      How can I manage my Diabetes?
# 9                     How is Dengue Fever diagnosed?
#
#                                     Réponse meditron  Temps d'exécution  \
# 0  What are the symptoms of Parkinson's Disease?\...          22.334797
# 1  How is HIV/AIDS diagnosed?\nHIV infection can ...          23.392662
# 2  How can I manage my Dengue Fever?\nHow can I m...          22.964650
# 3  Can Glaucoma be prevented? A qualitative study...          22.754100
# 4  Can Endometriosis be prevented?\nThe most impo...          22.679845
# 5  How can I manage my Multiple Sclerosis?".\n\n#...          22.650548
# 6  How is Cancer diagnosed?\nDuring a physical ex...          22.775442
# 7  What treatment options are available for Endom...          23.628584
# 8  How can I manage my Diabetes?\nWe’re here to h...          34.046091
# 9  How is Dengue Fever diagnosed?\nHow long does ...          24.812676
#
#                                     Réponse attendue
# 0  Treatment includes medications (levodopa) and ...
# 1  Treatment includes antiretroviral therapy (ART...
# 2  Diagnosis involves blood tests to detect the v...
# 3  Preventing Glaucoma involves regular eye exams...
# 4  Endometriosis is caused by the abnormal growth...
# 5  Parkinson's Disease symptoms include tremors, ...
# 6  Symptoms vary depending on the type and stage ...
# 7  Managing Endometriosis involves pain managemen...
# 8      Medication adherence, blood sugar monitoring.
# 9  Lifestyle changes include avoiding alcohol, pr...
